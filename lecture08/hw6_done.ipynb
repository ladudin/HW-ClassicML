# %% [markdown]
# Uncomment if you are using Colab

# %%
# !pip install crowd-kit==1.0.0

# %%
import hashlib
from collections import Counter, defaultdict
from functools import lru_cache
from typing import Dict, Iterable, List, Set, Tuple

import IPython.display as ipd
import matplotlib.pyplot as plt
import nltk
import numpy as np
import pandas as pd
import seaborn as sns
from crowdkit.aggregation import ROVER
from tabulate import tabulate
from tqdm.auto import tqdm

import re
import ipywidgets as widgets
from ipywidgets import interact
from sklearn.model_selection import train_test_split

plt.style.use("ggplot")

# %%
SEED = 42
np.random.seed(SEED)

# %% [markdown]
# Uncomment if you are using Colab

# %%
# %%bash
# mkdir -p ./data/audio
# wget -q https://raw.githubusercontent.com/vadim0912/ML2023/master/lecture08/data/noisy_text_aggregation_test.jsonl -P data/
# wget -q https://raw.githubusercontent.com/vadim0912/ML2023/master/lecture08/data/noisy_text_aggregation_train.jsonl -P data/
# wget -q https://raw.githubusercontent.com/vadim0912/ML2023/master/lecture08/data/noisy_text_aggregation_text_only.csv -P data/

# declare -a files=(
#   "98962310d56cd7095d9893f5ed657f81.wav"
#   "3c2875271fb918da312865549d444653.wav"
#   "b4f6a8d9e2eba8085d25d4122b52d55a.wav"
#   "ed0f6706f75681a7915fec15d336aca5.wav"
#   "f3dba379c6280536aaa65a56c4358268.wav"
# )

# for file in "${files[@]}"; do
#    wget -q https://raw.githubusercontent.com/vadim0912/ML2023/master/lecture08/data/audio/$file -P data/audio
# done

# %% [markdown]
# # Problem Statement

# %% [markdown]
# Дано:
# * три модели распознавания речи:
#     * `qnet`: [QuartzNet](https://arxiv.org/abs/1910.10261)
#     * `w2v`: [wav2vec XLS-R](https://arxiv.org/pdf/2111.09296.pdf)
#     * `w2v-tts`: тот же [wav2vec XLS-R](https://arxiv.org/pdf/2111.09296.pdf), но в дообучении использовались синтезированные (Text-To-Speech) данные
#
#
#  * модели имеют разную структуру (QuartzNet — сверточная, wav2vec — Трансформер) и обучались на разных данных => из их предсказаний можно построить композицию, которая сильнее любого кандидата в отдельности
#  * В тренировочном наборе данных ~ 60 тысяч примеров с референсной транскрипцией `text` (ground truth; истинный текст) и гипотезой каждой из моделей
#  * В тестовом наборе данных ~ 20 тысяч примеров с гипотезами от каждой из моделей, но без референсной транскрипции (ее нужно предсказать)
#  * Также доступен миллион фраз из того же домена (запросы к ассистентам), но без предсказаний моделей
#
# Задача: улучшить распознавание речи с помощью:
#  * агрегации транскрипций
#  * выбора лучшей транскрипции
#  * исправления ошибок в транскрипциях

# %%
train_df = pd.read_json("data/noisy_text_aggregation_train.jsonl", lines=True)

train_df.head()
# Out:
#                                task                  text  \
# 0  ed0f6706f75681a7915fec15d336aca5    дамира николаевича
# 1  3c2875271fb918da312865549d444653  антонине татариновой
# 2  f3dba379c6280536aaa65a56c4358268               жидкову
# 3  98962310d56cd7095d9893f5ed657f81            главатских
# 4  b4f6a8d9e2eba8085d25d4122b52d55a               мошкова
#
#                     qnet                   w2v               w2v_tts
# 0     дамира николаевича   до мира николаевича    домера николаевича
# 1  онпанине то тариновый  антонине татариновый  антонини татариновый
# 2               жит куву              жит куву               жидкову
# 3                 лалаки            главатских              главацки
# 4                мошкова               машкова               мошкова

# %%
MODEL_LIST = ["qnet", "w2v", "w2v_tts"]

# %%
for i, row in train_df.head(5).iterrows():
    labels = [row[model] == row["text"] for model in MODEL_LIST]

    row_df = (
        train_df.drop({"task", "text"}, axis=1)
        .iloc[[i]]
        .style.set_properties(
            **{"background-color": "#aaffaa"},
            subset=[model for model, label in zip(MODEL_LIST, labels) if label],
        )
        .set_properties(
            **{"background-color": "#ffaaaa"},
            subset=[model for model, label in zip(MODEL_LIST, labels) if not label],
        )
        .set_properties(width="150px")
    )
    ipd.display(row_df)
    ipd.display(ipd.Audio(f"data/audio/{row['task']}.wav"))
# Out:
# <style type="text/css">
# #T_52106_row0_col0 {
#   background-color: #aaffaa;
#   width: 150px;
# }
# #T_52106_row0_col1, #T_52106_row0_col2 {
#   background-color: #ffaaaa;
#   width: 150px;
# }
# </style>
# <table id="T_52106">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_52106_level0_col0" class="col_heading level0 col0" >qnet</th>
#       <th id="T_52106_level0_col1" class="col_heading level0 col1" >w2v</th>
#       <th id="T_52106_level0_col2" class="col_heading level0 col2" >w2v_tts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_52106_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_52106_row0_col0" class="data row0 col0" >дамира николаевича</td>
#       <td id="T_52106_row0_col1" class="data row0 col1" >до мира николаевича</td>
#       <td id="T_52106_row0_col2" class="data row0 col2" >домера николаевича</td>
#     </tr>
#   </tbody>
# </table>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# <style type="text/css">
# #T_ebb93_row0_col0, #T_ebb93_row0_col1, #T_ebb93_row0_col2 {
#   background-color: #ffaaaa;
#   width: 150px;
# }
# </style>
# <table id="T_ebb93">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ebb93_level0_col0" class="col_heading level0 col0" >qnet</th>
#       <th id="T_ebb93_level0_col1" class="col_heading level0 col1" >w2v</th>
#       <th id="T_ebb93_level0_col2" class="col_heading level0 col2" >w2v_tts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ebb93_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_ebb93_row0_col0" class="data row0 col0" >онпанине то тариновый</td>
#       <td id="T_ebb93_row0_col1" class="data row0 col1" >антонине татариновый</td>
#       <td id="T_ebb93_row0_col2" class="data row0 col2" >антонини татариновый</td>
#     </tr>
#   </tbody>
# </table>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# <style type="text/css">
# #T_71f6c_row0_col0, #T_71f6c_row0_col1 {
#   background-color: #ffaaaa;
#   width: 150px;
# }
# #T_71f6c_row0_col2 {
#   background-color: #aaffaa;
#   width: 150px;
# }
# </style>
# <table id="T_71f6c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_71f6c_level0_col0" class="col_heading level0 col0" >qnet</th>
#       <th id="T_71f6c_level0_col1" class="col_heading level0 col1" >w2v</th>
#       <th id="T_71f6c_level0_col2" class="col_heading level0 col2" >w2v_tts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_71f6c_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_71f6c_row0_col0" class="data row0 col0" >жит куву</td>
#       <td id="T_71f6c_row0_col1" class="data row0 col1" >жит куву</td>
#       <td id="T_71f6c_row0_col2" class="data row0 col2" >жидкову</td>
#     </tr>
#   </tbody>
# </table>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# <style type="text/css">
# #T_c53a6_row0_col0, #T_c53a6_row0_col2 {
#   background-color: #ffaaaa;
#   width: 150px;
# }
# #T_c53a6_row0_col1 {
#   background-color: #aaffaa;
#   width: 150px;
# }
# </style>
# <table id="T_c53a6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c53a6_level0_col0" class="col_heading level0 col0" >qnet</th>
#       <th id="T_c53a6_level0_col1" class="col_heading level0 col1" >w2v</th>
#       <th id="T_c53a6_level0_col2" class="col_heading level0 col2" >w2v_tts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c53a6_level0_row0" class="row_heading level0 row0" >3</th>
#       <td id="T_c53a6_row0_col0" class="data row0 col0" >лалаки</td>
#       <td id="T_c53a6_row0_col1" class="data row0 col1" >главатских</td>
#       <td id="T_c53a6_row0_col2" class="data row0 col2" >главацки</td>
#     </tr>
#   </tbody>
# </table>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# <style type="text/css">
# #T_717df_row0_col0, #T_717df_row0_col2 {
#   background-color: #aaffaa;
#   width: 150px;
# }
# #T_717df_row0_col1 {
#   background-color: #ffaaaa;
#   width: 150px;
# }
# </style>
# <table id="T_717df">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_717df_level0_col0" class="col_heading level0 col0" >qnet</th>
#       <th id="T_717df_level0_col1" class="col_heading level0 col1" >w2v</th>
#       <th id="T_717df_level0_col2" class="col_heading level0 col2" >w2v_tts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_717df_level0_row0" class="row_heading level0 row0" >4</th>
#       <td id="T_717df_row0_col0" class="data row0 col0" >мошкова</td>
#       <td id="T_717df_row0_col1" class="data row0 col1" >машкова</td>
#       <td id="T_717df_row0_col2" class="data row0 col2" >мошкова</td>
#     </tr>
#   </tbody>
# </table>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
test_df = pd.read_json("data/noisy_text_aggregation_test.jsonl", lines=True)

test_df.head()
# Out:
#                                task                                qnet  \
# 0  73aff8bc8d99278c6ca6d1ac243557e3                                дели
# 1  ba8443f3cc91e56667278db36dea02b7  вектор упавнович чунула к лещенуму
# 2  af346fae1d5686a357e32710c5d4f13e                     риме менниковой
# 3  262fda7ab40a8417b99ecb314b3f7405               александровик провичо
# 4  08bd8fb35ceaf2843734ffeb389f2283                        я ро славцов
#
#                                w2v                               w2v_tts
# 0                             зили                                  зили
# 1  виктору павловичу новокрещеному  виктору павлновичу навокрещинову  оо
# 2                римми мельниковой                     рымми мельниковой
# 3           александру викторовичу                александру викторовичу
# 4                       ерославцев                            ярославцев

# %%
def hash_remainder(str_, base: int = 10) -> int:
    return int(hashlib.md5(str_.encode()).hexdigest(), 16) % base


train_mask = train_df["task"].apply(lambda x: hash_remainder(x, 10) <= 7)

val_df = train_df[~train_mask]
train_df = train_df[train_mask]

# %%
train_df.head()
# Out:
#                                task                            text  \
# 0  ed0f6706f75681a7915fec15d336aca5              дамира николаевича
# 2  f3dba379c6280536aaa65a56c4358268                         жидкову
# 3  98962310d56cd7095d9893f5ed657f81                      главатских
# 4  b4f6a8d9e2eba8085d25d4122b52d55a                         мошкова
# 5  6bde4ff468980a927dd4f2e0a48e587f  светлану магомедовну федоренко
#
#                              qnet                              w2v  \
# 0              дамира николаевича              до мира николаевича
# 2                        жит куву                         жит куву
# 3                          лалаки                       главатских
# 4                         мошкова                          машкова
# 5  светланамога медавно фитаренка  светламны могомедовно ветаренка
#
#                           w2v_tts
# 0              домера николаевича
# 2                         жидкову
# 3                        главацки
# 4                         мошкова
# 5  светлану магомедовну фитаренка

# %%
test_df.head()
# Out:
#                                task                                qnet  \
# 0  73aff8bc8d99278c6ca6d1ac243557e3                                дели
# 1  ba8443f3cc91e56667278db36dea02b7  вектор упавнович чунула к лещенуму
# 2  af346fae1d5686a357e32710c5d4f13e                     риме менниковой
# 3  262fda7ab40a8417b99ecb314b3f7405               александровик провичо
# 4  08bd8fb35ceaf2843734ffeb389f2283                        я ро славцов
#
#                                w2v                               w2v_tts
# 0                             зили                                  зили
# 1  виктору павловичу новокрещеному  виктору павлновичу навокрещинову  оо
# 2                римми мельниковой                     рымми мельниковой
# 3           александру викторовичу                александру викторовичу
# 4                       ерославцев                            ярославцев

# %% [markdown]
# ### Построим языковую модель

# %%
text_data = pd.read_csv("data/noisy_text_aggregation_text_only.csv", header=None)

# %%
text_by_length = text_data[0].str.len().value_counts().sort_index()

plt.plot(text_by_length.index, text_by_length.values)
plt.xlabel("length")
plt.ylabel("number of pages")
plt.xscale("log")

# %%
text_by_words = text_data[0].str.split().apply(len).value_counts().sort_index()

plt.plot(text_by_words.index, text_by_words.values)
plt.xlabel("words")
plt.ylabel("number of pages")
plt.xscale("log")

# %%
tokenized_texts = text_data[0].apply(str.split)
tokenized_texts
# Out:
# 0                                                    [алиби]
# 1                                                   [сказка]
# 2                  [найди, в, нете, мульт, стальной, гигант]
# 3                                               [мона, лиза]
# 4                   [смотреть, сериал, восемь, с, половиной]
#                                  ...
# 1014216    [афина, какие, военные, положения, в, россии, ...
# 1014217          [джой, могут, ли, соседи, вызвать, полицию]
# 1014218                     [сбер, с, каким, животным, себя]
# 1014219    [афина, какие, реквизиты, необходимы, для, про...
# 1014220    [афина, чем, является, обшивка, фермерских, фю...
# Name: 0, Length: 1014221, dtype: object

# %%
train_set, val_set = train_test_split(
    tokenized_texts, test_size=0.05, random_state=SEED
)

# %% [markdown]
# # N-gram Language Model
#
# $$
#     P(w_1, \dots, w_k) = \prod_t P(w_t \mid w_{t - n + 1}, \dots, w_{t - 1}).
# $$
#
# $$
#     P(w_t \mid w_{t - n + 1}, \dots, w_{t - 1}) \approx \frac{\text{count} (w_{t - n + 1} \dots, w_{t - 1}, w_t)}{\displaystyle \sum_w \text{count} (w_{t - n + 1} \dots w_{t - 1}, w)}=\frac{\text{count} (w_{t - n + 1} \dots, w_{t - 1}, w_t)}{\text{count} (w_{t - n + 1} \dots w_{t - 1})}
# $$

# %%
BOS = "<BOS>"
EOS = "<EOS>"

ngrams_config = {
    "pad_left": True,
    "pad_right": True,
    "left_pad_symbol": BOS,
    "right_pad_symbol": EOS,
}


def build_ngram_counts(
    tokenized_texts: Iterable[Iterable[str]], n: int
) -> Dict[Tuple[str, ...], Dict[str, int]]:
    """
    встречаемость слова при условии (n - 1) предыдущего слова

    для n = 2:
        {
            ('добрый',): {'день': 273, 'вечер': 55, 'путь': 8, ...},
            ('машинное',): {'масло': 2, 'отделение': 6, 'обучение': 4, ...}
            ...
        }

    для n = 3:
         {
            ('<BOS>', '<BOS>'): {'мэр': 22, 'выпуск': 40, ...},
            ('<BOS>', 'мэр'): {'москвы': 3, 'перми': 3, ...},
            ...
        }
    """

    counts = defaultdict(Counter)

    for text in tokenized_texts:
        for ngram in nltk.ngrams(text, n, **ngrams_config):
            prefix = ngram[:-1]
            token = ngram[-1]
            counts[prefix][token] += 1

    return counts

# %%
class LanguageModel:
    def __init__(self, tokenized_texts: Iterable[Iterable[str]], n: int) -> None:
        self.n: int = n
        self.probs: Dict[Tuple[str, ...], Dict[str, float]] = defaultdict(Counter)
        ngrams = build_ngram_counts(tokenized_texts, n)
        for prefix, distribution in ngrams.items():
            total_count = sum(distribution.values())
            self.probs[prefix] = Counter({
                token: count / total_count for token, count in distribution.items()
            })
            
    def get_token_distribution(self, prefix: List[str]) -> Dict[str, float]:
        prefix = prefix[max(0, len(prefix) - self.n + 1) :]
        prefix = [BOS] * (self.n - 1 - len(prefix)) + prefix
        return self.probs[tuple(prefix)]

    def get_next_token_prob(self, prefix: List[str], token: str) -> float:
        return self.get_token_distribution(prefix)[token]

    def perplexity(self,
                   tokenized_texts: Iterable[Iterable[str]],
                   min_logprob: float = np.log(10**-50.0),
                  ) -> float:
        logprobs_sum: float = 0.0
        N: int = 0
        for tokens in tokenized_texts:
            prefix = [BOS] * (self.n - 1)
            padded_tokens = tokens + [EOS]
            for token in padded_tokens:
                logprob = np.log(self.get_next_token_prob(prefix, token))
                prefix = prefix[1:] + [token]
                logprobs_sum += max(logprob, min_logprob)
            N += len(padded_tokens)
        return np.exp(-logprobs_sum / N)

# %%
# %%time

model = LanguageModel(train_set, n=2)
# Out:
# CPU times: total: 8.17 s
# Wall time: 8.19 s

# %%
def plot_distribution(
    distribution: Dict[str, float],
    top_k: int = None,
    title: str = None,
    xlim: bool = True,
) -> None:
    data = sorted(distribution.items(), key=lambda x: -x[1])
    if top_k:
        data = data[:top_k]

    with plt.xkcd():
        plt.barh([word for word, count in data], [count for word, count in data])
        if xlim:
            plt.xlim([0, 1])
        if title:
            plt.title(title)
        plt.gca().invert_yaxis()
        plt.xlabel("probability")
        plt.grid()
        plt.show()


for word in ("хочу", "искусственный"):
    plot_distribution(model.probs[(word,)], top_k=15, title=word + " ...")
# Out:
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.

# %%
model.perplexity(val_set)
# Out:
# C:\Users\vald_\AppData\Local\Temp\ipykernel_24984\3156741759.py:30: RuntimeWarning: divide by zero encountered in log
#   logprob = np.log(self.get_next_token_prob(prefix, token))
# 289388.3456147256

# %%
len({token for tokens in train_set for token in tokens})
# Out:
# 130077

# %% [markdown]
# ### Laplace Smoothing

# %%
class LaplaceLanguageModel(LanguageModel):
    def __init__(
        self, tokenized_texts: Iterable[Iterable[str]], n: int, delta: float = 1.0
    ):
        self.n = n
        ngram_counts = build_ngram_counts(tokenized_texts, n)

        self.vocab = {
            token for distribution in ngram_counts.values() for token in distribution
        }

        self.probs = defaultdict(Counter)

        for prefix, distribution in ngram_counts.items():
            norm: float = sum(distribution.values()) + delta * len(self.vocab)
            self.probs[prefix] = {
                token: (count + delta) / norm for token, count in distribution.items()
            }

    def get_token_distribution(self, prefix: List[str]) -> Dict[str, float]:
        distribution: Dict[str, float] = super().get_token_distribution(prefix)
        missing_prob_total: float = 1.0 - sum(distribution.values())
        missing_prob = missing_prob_total / max(1, len(self.vocab) - len(distribution))
        return {token: distribution.get(token, missing_prob) for token in self.vocab}

    def get_next_token_prob(self, prefix: List[str], next_token: str):
        distribution: Dict[str, float] = super().get_token_distribution(prefix)
        if next_token in distribution:
            return distribution[next_token]
        else:
            missing_prob_total = 1.0 - sum(distribution.values())
            return max(0, missing_prob_total) / max(
                1, len(self.vocab) - len(distribution)
            )

# %%
for n in (2, 3):
    laplace_model = LaplaceLanguageModel(train_set, n=n)
    print(f"{n}: {laplace_model.perplexity(val_set)}")
# Out:
# 2: 1317.4820149073462
# 3: 4432.507910137031

# %%
delta_model = LaplaceLanguageModel(train_set, n=2, delta=1e-4)

# %%
delta_model.perplexity(val_set)
# Out:
# 96.39488387850265

# %%
for word in ("хочу", "искусственный"):
    plot_distribution(delta_model.probs[(word,)], top_k=15, title=word + " ...")
# Out:
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.

# %% [markdown]
# # Metrics

# %%
def dummy_edit_distance(ref: Iterable, hyp: Iterable) -> int:
    """
    dummy levenshtein implementation O(3^n)
    """
    if not ref:
        return len(hyp)
    if not hyp:
        return len(ref)
    return min(
        edit_distance(ref[1:], hyp[1:]) + (ref[0] != hyp[0]),  # Correct / Insertion
        edit_distance(ref, hyp[1:]) + 1,  # Deletion
        edit_distance(ref[1:], hyp) + 1,  # Substitution
    )


def edit_distance(ref: Iterable, hyp: Iterable, plot: bool = False) -> int:
    """
    dynamic programming levenshtein implementation O(n^2)
    """

    dist = np.zeros((len(hyp) + 1, len(ref) + 1), dtype=np.int32)

    dist[:, 0] = np.arange(len(hyp) + 1)
    dist[0, :] = np.arange(len(ref) + 1)

    for i, r in enumerate(hyp, start=1):
        for j, h in enumerate(ref, start=1):
            dist[i, j] = min(
                dist[i - 1, j - 1] + (r != h), dist[i, j - 1] + 1, dist[i - 1, j] + 1
            )
    if plot:
        sns.heatmap(
            pd.DataFrame(dist, index=[" "] + list(hyp), columns=[" "] + list(ref)),
            annot=True,
            cmap="coolwarm_r",
            linewidth=2,
        )
        plt.tick_params(
            axis="both",
            which="major",
            labelsize=14,
            left=False,
            labelbottom=False,
            bottom=False,
            top=False,
            labeltop=True,
        )
        plt.yticks(rotation=0)
        plt.show()

    return dist[-1, -1]

# %%
def error_rate(*, refs: Iterable[Iterable], hyps: Iterable[Iterable]) -> float:
    """
    ignoring hypotheses with empty references
    """

    wrong_words, all_words = 0, 0

    for ref, hyp in tqdm(zip(refs, hyps), total=len(refs)):
        if len(ref) > 0:
            wrong_words += edit_distance(ref, hyp)
            all_words += len(ref)
        else:
            continue
    return wrong_words / all_words if all_words > 0 else 0.0


def wer(*, refs: Iterable[str], hyps: Iterable[str]) -> float:
    """
    Word Error Rate
    """
    return error_rate(
        refs=[ref.split() for ref in refs], hyps=[hyp.split() for hyp in hyps]
    )


def cer(*, refs: Iterable[str], hyps: Iterable[str]) -> float:
    """
    Character Error Rate
    """
    return error_rate(refs=refs, hyps=hyps)

# %%
class PrettyDict(dict):
    def __repr__(self):
        return tabulate(
            sorted(
                [[k, round(v * 100, 2)] for k, v in self.items()],
                key=lambda x: x[1],
                reverse=True,
            ),
            tablefmt="orgtbl",
            headers=("method", "WER, %"),
        )

def get_cer():
    return PrettyDict(
                    {model: cer(hyps=val_df[model], refs=val_df["text"]) for model in MODEL_LIST}
                    )
def get_wer():
    return PrettyDict(
                    {model: wer(hyps=val_df[model], refs=val_df["text"]) for model in MODEL_LIST}
                    )

# %% [markdown]
# # Oracle WER и CER
#
# если представить, что мы идеально выбираем лучшую из трех гипотез (Оракул), какими будут WER и CER?\
# таким образом оценим нижнюю границу Rescoring-системы

# %%
def get_best_transcription(ref: Iterable[str], hyps: Iterable[Iterable[str]]):
    return hyps[np.array([edit_distance(ref, hyp) for hyp in hyps]).argmin()]

# %%
oracle_hyp = val_df.apply(
    lambda row: " ".join(
        get_best_transcription(
            ref=row["text"].split(), hyps=[row[model].split() for model in MODEL_LIST]
        )
    ),
    axis=1,
)

# %%
method2wer = get_wer()
method2wer["oracle_wer"] = wer(refs=val_df["text"], hyps=oracle_hyp)
method2wer
# Out:
#   0%|          | 0/12354 [00:00<?, ?it/s]
#   0%|          | 0/12354 [00:00<?, ?it/s]
#   0%|          | 0/12354 [00:00<?, ?it/s]
#   0%|          | 0/12354 [00:00<?, ?it/s]
# | method     |   WER, % |
# |------------+----------|
# | qnet       |    94.87 |
# | w2v_tts    |    71.06 |
# | w2v        |    65.46 |
# | oracle_wer |    49.48 |

# %%
method2wer = get_cer()
method2wer["oracle_cer"] = cer(refs=val_df["text"], hyps=oracle_hyp)
method2wer
# Out:
#   0%|          | 0/12354 [00:00<?, ?it/s]
#   0%|          | 0/12354 [00:00<?, ?it/s]
#   0%|          | 0/12354 [00:00<?, ?it/s]
#   0%|          | 0/12354 [00:00<?, ?it/s]
# | method     |   WER, % |
# |------------+----------|
# | qnet       |    23.35 |
# | w2v_tts    |    14.3  |
# | w2v        |    12.28 |
# | oracle_cer |    12.13 |

# %% [markdown]
# Как мы видим, w2v почти достигает максимума в рескоринге по CER, но по WER качество заметно хуже

# %% [markdown]
# ## Улучшим rescoring по WER, применяя языковую модель

# %%
delta_char_model = LaplaceLanguageModel(n=6, tokenized_texts=train_df['text'], delta=1e-2)

# %%
delta_char_model.perplexity(val_df['text'].apply(list))
# Out:
# 3.490606733642127

# %%
def best(sentences: Iterable[str]):
    return ' '.join(min([[sent.split()] for sent in sentences], key=delta_model.perplexity)[0])

# %%
def best_char(sentences, n=1):
    res = sorted([[list(sent)] for sent in sentences], key=delta_char_model.perplexity)
    return [''.join(letters[0]) for letters in res][0:n]
    # return ''.join(min([[list(sent)] for sent in sentences], key=delta_char_model.perplexity)[0])

# %%
best_char(['привет мри', 'привет мир'], n=2)
# Out:
# ['привет мри', 'привет мир']

# %%
max_likelihood_utterances = val_df.apply(
    lambda row: best_char(row[model] for model in MODEL_LIST[1:])[0],
    axis=1,
)

# %%
method2wer = get_wer()
method2wer["rescoring"] = wer(hyps=val_df["text"], refs=max_likelihood_utterances)
method2wer
# Out:
#   0%|          | 0/12354 [00:00<?, ?it/s]
#   0%|          | 0/12354 [00:00<?, ?it/s]
#   0%|          | 0/12354 [00:00<?, ?it/s]
#   0%|          | 0/12354 [00:00<?, ?it/s]
# | method    |   WER, % |
# |-----------+----------|
# | qnet      |    94.87 |
# | w2v_tts   |    71.06 |
# | w2v       |    65.46 |
# | rescoring |    49.72 |

# %% [markdown]
# Таким образом мы почти добились максимума по WER в rescoring

# %% [markdown]
# ## Попробуем увеличить качество, исправляя ошибки

# %% [markdown]
# С помощью выравнивания посмотрим, где модели чаще всего ошибаются

# %%
def align(ref: Iterable, hyp: Iterable) -> List[Tuple[str, str, str]]:
    dist = np.zeros((len(hyp) + 1, len(ref) + 1), dtype=np.int32)

    dist[:, 0] = np.arange(len(hyp) + 1)
    dist[0, :] = np.arange(len(ref) + 1)

    cache = [[None] * (len(ref) + 1) for _ in range(len(hyp) + 1)]

    for i, h in enumerate(hyp, start=1):
        cache[i][0] = ("I", "%", h)

    for i, r in enumerate(ref, start=1):
        cache[0][i] = ("D", r, "#")

    for i, h in enumerate(hyp, start=1):
        for j, r in enumerate(ref, start=1):
            cases = []

            if r == h:
                cases.append((dist[i - 1, j - 1], ("C", r, h)))
            else:
                cases.append((dist[i - 1, j - 1] + 1, ("S", r, h)))
            cases.append((dist[i, j - 1] + 1, ("D", r, "#")))
            cases.append((dist[i - 1, j] + 1, ("I", "%", h)))

            dist[i, j], cache[i][j] = min(cases, key=lambda x: x[0])

    alignment = []
    i, j = len(hyp), len(ref)

    while i != 0 or j != 0:
        action, r, h = cache[i][j]
        alignment.append((action, r, h))
        if action in {"C", "S"}:
            i -= 1
            j -= 1
        elif action == "I":
            i -= 1
        else:
            j -= 1

    return alignment[::-1]

# %%
all_errors_s = Counter([tup[1:] for _, row in train_df.iterrows() for tup in align(row[1], row[4]) if tup[0] == 'S'])
all_errors_s = sorted(all_errors_s.items(), key=lambda error: -error[1])
all_errors_s
# Out:
# [(('а', 'о'), 5872),
#  (('о', 'а'), 4875),
#  (('и', 'е'), 4249),
#  (('е', 'и'), 3240),
#  (('о', ' '), 1937),
#  (('о', 'у'), 1514),
#  (('д', 'т'), 941),
#  (('е', 'я'), 872),
#  (('я', 'е'), 733),
#  (('е', ' '), 718),
#  (('у', 'о'), 675),
#  (('с', 'ц'), 640),
#  (('э', 'е'), 575),
#  (('т', 'д'), 546),
#  (('й', 'е'), 428),
#  (('г', 'к'), 424),
#  (('ф', 'в'), 418),
#  (('о', 'е'), 414),
#  (('з', 'с'), 412),
#  (('е', 'а'), 397),
#  (('о', 'ы'), 365),
#  (('с', 'з'), 360),
#  ((' ', 'о'), 359),
#  (('б', 'п'), 350),
#  (('й', 'и'), 349),
#  (('а', ' '), 323),
#  (('н', 'м'), 318),
#  (('у', 'л'), 299),
#  (('ц', 'с'), 283),
#  (('и', ' '), 282),
#  (('ь', 'и'), 280),
#  (('и', 'л'), 274),
#  (('к', 'г'), 268),
#  (('ы', 'а'), 254),
#  (('а', 'ы'), 253),
#  (('ы', 'о'), 227),
#  (('е', 'ы'), 227),
#  (('с', ' '), 226),
#  (('е', 'о'), 220),
#  (('а', 'е'), 218),
#  (('ж', 'ш'), 214),
#  ((' ', 'а'), 212),
#  (('и', 'ь'), 206),
#  (('я', 'и'), 205),
#  (('в', 'г'), 197),
#  (('м', 'н'), 197),
#  (('и', 'я'), 193),
#  (('я', 'й'), 192),
#  (('д', ' '), 191),
#  (('о', 'л'), 184),
#  (('в', 'ф'), 183),
#  (('и', 'ы'), 170),
#  (('е', 'й'), 167),
#  (('э', 'а'), 160),
#  (('л', 'в'), 155),
#  (('и', 'й'), 149),
#  (('ш', 'щ'), 147),
#  ((' ', 'с'), 142),
#  ((' ', 'е'), 139),
#  (('н', ' '), 135),
#  (('п', 'б'), 135),
#  (('б', 'в'), 134),
#  (('у', ' '), 127),
#  (('а', 'я'), 125),
#  (('и', 'а'), 124),
#  (('я', 'о'), 121),
#  (('в', 'б'), 119),
#  (('ч', 'т'), 118),
#  (('э', 'о'), 118),
#  (('р', 'л'), 114),
#  (('ь', 'е'), 114),
#  (('ш', 'с'), 114),
#  (('а', 'у'), 112),
#  (('в', 'л'), 110),
#  (('ы', 'и'), 108),
#  (('т', ' '), 107),
#  (('к', ' '), 104),
#  (('я', 'а'), 103),
#  (('ь', ' '), 101),
#  ((' ', 'у'), 100),
#  (('т', 'к'), 100),
#  (('й', ' '), 97),
#  (('о', 'в'), 92),
#  (('э', 'ы'), 91),
#  ((' ', 'т'), 89),
#  ((' ', 'и'), 87),
#  (('ж', 'ч'), 87),
#  (('и', 'н'), 86),
#  (('д', 'г'), 85),
#  (('и', 'ю'), 84),
#  (('я', ' '), 82),
#  (('ф', ' '), 82),
#  (('у', 'ы'), 81),
#  (('ч', ' '), 81),
#  (('о', 'т'), 80),
#  (('й', 'я'), 79),
#  (('э', ' '), 78),
#  (('у', 'ю'), 77),
#  (('л', 'р'), 77),
#  (('в', ' '), 75),
#  (('ф', 'с'), 74),
#  (('м', ' '), 73),
#  (('е', 'ю'), 72),
#  (('л', 'о'), 72),
#  (('з', 'д'), 72),
#  (('р', 'ж'), 72),
#  (('р', ' '), 71),
#  (('о', 'н'), 71),
#  (('ц', 'т'), 69),
#  (('к', 'т'), 69),
#  (('г', ' '), 68),
#  (('э', 'и'), 68),
#  (('й', 'ю'), 67),
#  (('ж', 'ь'), 66),
#  ((' ', 'м'), 65),
#  (('л', 'н'), 65),
#  (('о', 'й'), 64),
#  (('с', 'т'), 64),
#  (('з', ' '), 64),
#  (('ш', 'ж'), 63),
#  (('р', 'в'), 63),
#  (('а', 'м'), 63),
#  (('г', 'в'), 60),
#  (('о', 'с'), 59),
#  ((' ', 'ы'), 59),
#  (('е', 'ь'), 59),
#  (('х', 'с'), 57),
#  (('о', 'м'), 57),
#  (('ы', 'е'), 57),
#  (('т', 'ч'), 57),
#  (('о', 'и'), 57),
#  (('л', ' '), 56),
#  (('у', 'а'), 56),
#  (('у', 'е'), 56),
#  ((' ', 'к'), 55),
#  ((' ', 'р'), 54),
#  (('о', 'г'), 53),
#  (('е', 'м'), 53),
#  (('э', 'я'), 53),
#  ((' ', 'э'), 52),
#  (('ц', ' '), 52),
#  (('ж', 'з'), 52),
#  (('н', 'л'), 51),
#  (('м', 'а'), 51),
#  (('ю', 'у'), 51),
#  (('ю', 'е'), 50),
#  (('л', 'у'), 50),
#  (('р', 'е'), 49),
#  (('г', 'д'), 48),
#  (('в', 'у'), 48),
#  (('е', 'э'), 48),
#  (('а', 'и'), 47),
#  ((' ', 'г'), 47),
#  (('а', 'т'), 46),
#  (('а', 'к'), 46),
#  (('м', 'в'), 45),
#  (('о', 'я'), 45),
#  (('ы', 'у'), 44),
#  (('н', 'а'), 44),
#  (('б', ' '), 44),
#  (('й', 'ь'), 43),
#  (('с', 'щ'), 42),
#  (('р', 'а'), 42),
#  (('ч', 'д'), 42),
#  (('к', 'х'), 42),
#  ((' ', 'н'), 41),
#  (('т', 'ц'), 41),
#  (('и', 'о'), 41),
#  (('л', 'а'), 40),
#  (('н', 'и'), 40),
#  (('с', 'ш'), 40),
#  (('д', 'и'), 40),
#  (('е', 'н'), 39),
#  (('м', 'у'), 39),
#  ((' ', 'л'), 39),
#  (('о', 'к'), 39),
#  (('й', 'ы'), 38),
#  (('й', 'а'), 38),
#  (('в', 'а'), 38),
#  (('ж', ' '), 38),
#  (('а', 'в'), 38),
#  (('э', 'й'), 38),
#  ((' ', 'в'), 38),
#  (('т', 'с'), 37),
#  (('т', 'о'), 37),
#  (('к', 'п'), 37),
#  (('ы', ' '), 37),
#  (('б', 'м'), 37),
#  (('н', 'е'), 37),
#  (('я', 'ю'), 37),
#  (('р', 'и'), 36),
#  (('щ', 'ч'), 35),
#  (('х', 'к'), 35),
#  (('ь', 'й'), 34),
#  (('ъ', ' '), 34),
#  (('р', 'ь'), 34),
#  (('а', 'л'), 33),
#  (('п', ' '), 33),
#  (('о', 'р'), 33),
#  (('е', 'т'), 33),
#  (('д', 'н'), 33),
#  (('в', 'о'), 33),
#  (('в', 'м'), 32),
#  (('д', 'е'), 32),
#  (('а', 'н'), 31),
#  (('р', 'о'), 31),
#  (('й', 'о'), 31),
#  (('х', ' '), 31),
#  (('д', 'ц'), 31),
#  (('н', 'д'), 31),
#  (('н', 'о'), 31),
#  (('и', 'с'), 30),
#  (('ь', 'я'), 30),
#  (('ь', 'н'), 30),
#  ((' ', 'я'), 29),
#  (('с', 'а'), 29),
#  (('й', 'х'), 28),
#  (('л', 'г'), 28),
#  (('у', 'и'), 28),
#  (('л', 'и'), 28),
#  (('ю', ' '), 28),
#  (('в', 'п'), 28),
#  (('у', 'в'), 28),
#  (('е', 'у'), 28),
#  ((' ', 'й'), 28),
#  (('с', 'е'), 28),
#  (('м', 'б'), 28),
#  (('р', 'у'), 28),
#  (('ь', 'р'), 27),
#  (('а', 'й'), 27),
#  (('и', 'т'), 27),
#  (('п', 'к'), 27),
#  (('к', 'а'), 26),
#  (('с', 'о'), 26),
#  (('х', 'г'), 26),
#  ((' ', 'д'), 26),
#  (('е', 'л'), 25),
#  (('в', 'е'), 25),
#  (('ш', ' '), 25),
#  (('г', 'а'), 25),
#  (('и', 'у'), 25),
#  (('о', 'ю'), 25),
#  (('з', 'ц'), 25),
#  (('ж', 'е'), 24),
#  (('и', 'м'), 24),
#  (('о', 'э'), 24),
#  (('д', 'а'), 24),
#  (('ы', 'й'), 24),
#  (('с', 'ь'), 24),
#  ((' ', 'з'), 23),
#  (('п', 'о'), 23),
#  (('ь', 'м'), 23),
#  (('т', 'е'), 23),
#  (('ч', 'щ'), 22),
#  (('м', 'о'), 22),
#  (('б', 'г'), 22),
#  (('ц', 'ь'), 22),
#  ((' ', 'ь'), 21),
#  (('з', 'т'), 21),
#  (('е', 'р'), 21),
#  (('в', 'с'), 21),
#  (('д', 'ч'), 21),
#  (('б', 'д'), 21),
#  (('о', 'п'), 21),
#  (('т', 'ь'), 20),
#  (('ш', 'ч'), 20),
#  ((' ', 'п'), 20),
#  (('а', 'г'), 20),
#  (('л', 'д'), 19),
#  (('п', 'т'), 19),
#  (('н', 'ь'), 19),
#  (('б', 'о'), 19),
#  (('ф', 'х'), 19),
#  (('д', 'ь'), 19),
#  (('с', 'и'), 19),
#  (('р', 'т'), 19),
#  (('а', 'с'), 19),
#  (('ь', 'ы'), 19),
#  ((' ', 'б'), 19),
#  (('л', 'м'), 18),
#  (('к', 'о'), 18),
#  (('й', 'н'), 18),
#  (('с', 'я'), 18),
#  (('т', 'а'), 18),
#  (('р', 'н'), 18),
#  (('т', 'у'), 18),
#  (('г', 'е'), 18),
#  (('и', 'э'), 17),
#  (('я', 'н'), 17),
#  (('м', 'ь'), 17),
#  (('х', 'ф'), 17),
#  (('а', 'д'), 17),
#  (('в', 'и'), 17),
#  (('а', 'э'), 17),
#  (('т', 'н'), 17),
#  (('м', 'и'), 17),
#  (('р', 'ш'), 17),
#  ((' ', 'ц'), 17),
#  (('ю', 'и'), 16),
#  (('л', 'е'), 16),
#  (('у', 'м'), 16),
#  (('г', 'б'), 16),
#  (('ц', 'д'), 16),
#  (('м', 'л'), 16),
#  (('д', 'ы'), 16),
#  (('о', 'д'), 16),
#  (('н', 'у'), 16),
#  (('с', 'к'), 16),
#  (('к', 'и'), 16),
#  (('м', 'е'), 16),
#  (('с', 'ч'), 16),
#  (('ь', 'ю'), 15),
#  (('в', 'д'), 15),
#  (('е', 'д'), 15),
#  (('в', 'р'), 15),
#  (('л', 'ь'), 15),
#  (('о', 'ж'), 15),
#  (('х', 'щ'), 15),
#  (('д', 'о'), 15),
#  (('т', 'п'), 15),
#  (('б', 'е'), 15),
#  (('ж', 'д'), 15),
#  (('ч', 'ж'), 15),
#  (('т', 'и'), 15),
#  (('б', 'а'), 15),
#  (('т', 'з'), 15),
#  (('р', 'д'), 14),
#  (('я', 'м'), 14),
#  (('з', 'ж'), 14),
#  (('е', 'с'), 14),
#  (('ф', 'п'), 14),
#  (('н', 'й'), 14),
#  (('г', 'о'), 14),
#  (('д', 'у'), 14),
#  (('ъ', 'ь'), 14),
#  (('й', 'т'), 14),
#  (('а', 'р'), 14),
#  (('ч', 'ш'), 13),
#  (('д', 'в'), 13),
#  (('ц', 'ч'), 13),
#  (('ь', 'т'), 13),
#  (('в', 'т'), 13),
#  (('с', 'у'), 13),
#  (('и', 'д'), 13),
#  (('д', 'б'), 13),
#  (('с', 'в'), 13),
#  (('л', 'й'), 13),
#  (('н', 'т'), 13),
#  (('ы', 'я'), 13),
#  (('в', 'ы'), 12),
#  (('ь', 'д'), 12),
#  (('е', 'в'), 12),
#  (('ч', 'и'), 12),
#  (('ч', 'ь'), 12),
#  (('б', 'ы'), 12),
#  (('н', 'ы'), 12),
#  (('у', 'р'), 12),
#  (('э', 'т'), 12),
#  (('д', 'з'), 12),
#  (('э', 'н'), 12),
#  (('а', 'ь'), 12),
#  (('л', 'з'), 12),
#  (('р', 'г'), 12),
#  (('п', 'в'), 12),
#  (('э', 'л'), 12),
#  (('т', 'ы'), 12),
#  (('ь', 'ч'), 11),
#  (('ь', 'в'), 11),
#  ((' ', 'ю'), 11),
#  (('в', 'й'), 11),
#  (('ц', 'е'), 11),
#  (('ж', 'с'), 11),
#  (('с', 'ф'), 11),
#  (('о', 'з'), 11),
#  (('э', 'к'), 11),
#  ((' ', 'х'), 11),
#  (('и', 'в'), 11),
#  (('т', 'в'), 11),
#  (('щ', 'ш'), 10),
#  (('в', 'ю'), 10),
#  (('ь', 'с'), 10),
#  (('н', 'я'), 10),
#  (('о', 'ь'), 10),
#  (('у', 'т'), 10),
#  (('н', 'в'), 10),
#  (('л', 'ы'), 10),
#  (('ь', 'а'), 10),
#  (('й', 'м'), 10),
#  (('г', 'т'), 10),
#  (('е', 'б'), 10),
#  (('е', 'к'), 10),
#  (('о', 'х'), 10),
#  (('в', 'к'), 10),
#  (('т', 'л'), 10),
#  (('ж', 'и'), 10),
#  (('й', 'с'), 10),
#  (('г', 'з'), 10),
#  (('й', 'к'), 9),
#  (('в', 'н'), 9),
#  (('о', 'ш'), 9),
#  (('щ', 'с'), 9),
#  (('в', 'х'), 9),
#  (('д', 'ж'), 9),
#  (('ц', 'я'), 9),
#  (('з', 'ь'), 9),
#  (('ж', 'р'), 9),
#  (('д', 'я'), 9),
#  (('к', 'м'), 9),
#  (('ц', 'з'), 9),
#  (('к', 'ц'), 9),
#  (('ф', 'к'), 9),
#  (('я', 'т'), 9),
#  (('й', 'л'), 9),
#  (('л', 'т'), 9),
#  (('б', 'и'), 9),
#  (('и', 'з'), 9),
#  (('к', 'е'), 9),
#  (('и', 'щ'), 9),
#  (('к', 'э'), 9),
#  (('з', 'у'), 9),
#  (('ь', 'к'), 8),
#  (('ы', 'н'), 8),
#  (('е', 'ч'), 8),
#  (('и', 'ч'), 8),
#  (('ф', 'и'), 8),
#  (('д', 'л'), 8),
#  (('п', 'ы'), 8),
#  (('г', 'м'), 8),
#  (('б', 'т'), 8),
#  (('с', 'л'), 8),
#  (('к', 'у'), 8),
#  (('л', 'ю'), 8),
#  (('я', 'ь'), 8),
#  (('в', 'з'), 8),
#  (('ю', 'о'), 8),
#  (('р', 'ы'), 8),
#  (('и', 'г'), 8),
#  (('и', 'р'), 8),
#  (('к', 'л'), 8),
#  (('х', 'в'), 8),
#  (('з', 'в'), 8),
#  (('г', 'х'), 8),
#  (('ь', 'о'), 8),
#  (('р', 'с'), 8),
#  (('м', 'э'), 8),
#  (('с', 'ю'), 8),
#  (('я', 'ы'), 8),
#  (('г', 'ы'), 8),
#  (('ь', 'л'), 7),
#  (('е', 'ш'), 7),
#  (('ш', 'и'), 7),
#  (('ж', 'в'), 7),
#  (('ц', 'в'), 7),
#  (('ц', 'о'), 7),
#  (('г', 'у'), 7),
#  (('у', 'н'), 7),
#  (('р', 'я'), 7),
#  (('з', 'и'), 7),
#  (('д', 'р'), 7),
#  (('ы', 'в'), 7),
#  (('к', 'ы'), 7),
#  (('ь', 'ж'), 7),
#  (('ш', 'е'), 7),
#  (('ш', 'ь'), 7),
#  (('ь', 'г'), 7),
#  (('ш', 'а'), 7),
#  (('ж', 'ц'), 7),
#  (('ц', 'ы'), 7),
#  ((' ', 'ш'), 7),
#  (('у', 'й'), 7),
#  (('о', 'б'), 7),
#  (('п', 'е'), 7),
#  (('ы', 'ь'), 7),
#  (('к', 'з'), 7),
#  (('р', 'п'), 7),
#  (('к', 'в'), 7),
#  (('м', 'й'), 7),
#  (('с', 'э'), 7),
#  (('ф', 'э'), 7),
#  ((' ', 'ф'), 6),
#  (('ь', 'у'), 6),
#  (('т', 'м'), 6),
#  (('ф', 'о'), 6),
#  (('к', 'с'), 6),
#  (('и', 'к'), 6),
#  (('ф', 'т'), 6),
#  (('л', 'к'), 6),
#  (('и', 'ц'), 6),
#  (('н', 'к'), 6),
#  (('м', 'ы'), 6),
#  (('й', 'у'), 6),
#  (('р', 'х'), 6),
#  (('д', 'с'), 6),
#  (('а', 'п'), 6),
#  (('к', 'д'), 6),
#  (('у', 'к'), 6),
#  (('б', 'л'), 6),
#  (('с', 'д'), 6),
#  (('л', 'п'), 6),
#  (('с', 'ы'), 6),
#  (('е', 'ц'), 6),
#  (('у', 'д'), 6),
#  (('п', 'ф'), 6),
#  (('и', 'х'), 6),
#  (('т', 'й'), 6),
#  (('й', 'ч'), 6),
#  (('д', 'к'), 6),
#  (('ы', 'т'), 6),
#  (('з', 'й'), 6),
#  (('р', 'к'), 6),
#  (('ф', 'щ'), 5),
#  (('е', 'г'), 5),
#  (('ц', 'у'), 5),
#  (('ж', 'а'), 5),
#  (('ц', 'и'), 5),
#  (('ф', 'л'), 5),
#  ((' ', 'ж'), 5),
#  (('з', 'е'), 5),
#  (('ч', 'н'), 5),
#  (('й', 'ш'), 5),
#  (('ж', 'о'), 5),
#  (('ф', 'ь'), 5),
#  (('к', 'я'), 5),
#  (('э', 'с'), 5),
#  (('й', 'д'), 5),
#  (('к', 'ь'), 5),
#  (('р', 'б'), 5),
#  (('р', 'м'), 5),
#  (('п', 'и'), 5),
#  (('х', 'а'), 5),
#  (('й', 'р'), 5),
#  (('к', 'р'), 5),
#  (('с', 'й'), 5),
#  (('н', 'г'), 5),
#  (('ч', 'я'), 5),
#  (('ш', 'в'), 5),
#  (('ж', 'у'), 5),
#  ((' ', 'ч'), 5),
#  (('г', 'л'), 5),
#  (('б', 'к'), 5),
#  (('ы', 'м'), 5),
#  (('в', 'я'), 5),
#  (('л', 'б'), 5),
#  (('л', 'я'), 5),
#  (('э', 'м'), 5),
#  (('г', 'и'), 5),
#  (('э', 'в'), 5),
#  ((' ', '-'), 5),
#  (('р', 'э'), 5),
#  (('ш', 'з'), 4),
#  (('ю', 'а'), 4),
#  (('ч', 'е'), 4),
#  (('а', 'ж'), 4),
#  (('г', 'ь'), 4),
#  (('м', 'я'), 4),
#  (('з', 'ю'), 4),
#  (('е', 'з'), 4),
#  (('с', 'м'), 4),
#  (('я', 'г'), 4),
#  (('у', 'с'), 4),
#  (('э', 'д'), 4),
#  (('ф', 'е'), 4),
#  (('п', 'э'), 4),
#  (('я', 'л'), 4),
#  (('х', 'ш'), 4),
#  (('ф', 'ы'), 4),
#  (('у', 'х'), 4),
#  (('ю', 'ь'), 4),
#  (('щ', 'ь'), 4),
#  (('м', 'ю'), 4),
#  (('х', 'т'), 4),
#  (('б', 'я'), 4),
#  (('з', 'а'), 4),
#  (('й', 'э'), 4),
#  (('й', 'в'), 4),
#  (('у', 'ь'), 4),
#  (('й', 'з'), 4),
#  (('р', 'ю'), 4),
#  (('ш', 'о'), 4),
#  (('о', 'ц'), 4),
#  (('я', 'с'), 4),
#  (('п', 'й'), 4),
#  (('п', 'д'), 4),
#  (('р', 'ф'), 4),
#  (('з', 'о'), 4),
#  (('л', 'э'), 4),
#  (('а', 'з'), 4),
#  (('р', 'з'), 4),
#  (('ь', 'ц'), 4),
#  (('ы', 'ю'), 4),
#  (('к', 'б'), 4),
#  (('и', 'п'), 4),
#  (('д', 'п'), 4),
#  (('ч', 'ц'), 3),
#  (('ю', 'ы'), 3),
#  (('ц', 'ж'), 3),
#  (('л', 'х'), 3),
#  (('о', 'ч'), 3),
#  (('ы', 'с'), 3),
#  (('н', 'р'), 3),
#  (('ь', 'ф'), 3),
#  (('т', 'р'), 3),
#  (('с', 'б'), 3),
#  (('т', 'я'), 3),
#  (('и', 'ф'), 3),
#  (('х', 'е'), 3),
#  (('е', 'ж'), 3),
#  (('м', 'п'), 3),
#  (('в', 'ь'), 3),
#  (('у', 'б'), 3),
#  (('г', 'н'), 3),
#  (('г', 'й'), 3),
#  (('п', 'а'), 3),
#  (('ь', 'х'), 3),
#  (('у', 'я'), 3),
#  (('ы', 'э'), 3),
#  (('г', 'ф'), 3),
#  (('в', 'ж'), 3),
#  (('э', 'р'), 3),
#  (('л', 'с'), 3),
#  (('э', 'ь'), 3),
#  (('б', 'у'), 3),
#  (('ю', 'л'), 3),
#  (('п', 'г'), 3),
#  (('ч', 'с'), 3),
#  (('е', 'х'), 3),
#  (('ж', 'л'), 3),
#  (('н', 'ц'), 3),
#  (('ц', 'л'), 3),
#  (('и', 'б'), 3),
#  (('ф', 'а'), 3),
#  (('ш', 'у'), 3),
#  (('к', 'н'), 3),
#  (('н', 'ю'), 3),
#  (('д', 'ф'), 3),
#  (('м', 'д'), 3),
#  (('г', 'р'), 3),
#  (('т', 'б'), 3),
#  (('р', 'й'), 3),
#  (('с', 'п'), 3),
#  (('т', 'г'), 3),
#  (('ы', 'з'), 3),
#  (('п', 'ь'), 3),
#  (('н', 'с'), 3),
#  (('ф', 'р'), 3),
#  (('ш', 'ф'), 3),
#  (('в', 'э'), 3),
#  (('д', 'ю'), 3),
#  (('л', 'ч'), 3),
#  (('а', 'ю'), 3),
#  (('ф', 'ш'), 3),
#  (('ы', 'л'), 3),
#  (('д', 'м'), 3),
#  (('з', 'р'), 3),
#  (('щ', 'я'), 3),
#  (('г', 'я'), 3),
#  (('ъ', 'в'), 3),
#  (('м', 'ф'), 3),
#  (('я', 'р'), 2),
#  (('й', 'г'), 2),
#  (('б', 'ч'), 2),
#  (('ъ', 'и'), 2),
#  (('ч', 'л'), 2),
#  (('ъ', 'т'), 2),
#  (('у', 'ж'), 2),
#  (('ю', 'м'), 2),
#  (('ь', 'щ'), 2),
#  (('э', 'б'), 2),
#  (('э', 'п'), 2),
#  (('ы', 'г'), 2),
#  (('с', 'р'), 2),
#  (('д', 'х'), 2),
#  (('ш', 'н'), 2),
#  (('х', 'и'), 2),
#  (('с', 'г'), 2),
#  (('х', 'п'), 2),
#  (('з', 'я'), 2),
#  (('м', 'т'), 2),
#  (('ф', 'у'), 2),
#  (('ж', 'т'), 2),
#  (('з', 'ы'), 2),
#  (('х', 'р'), 2),
#  (('д', 'э'), 2),
#  (('ц', 'ш'), 2),
#  (('ч', 'к'), 2),
#  (('д', 'й'), 2),
#  (('ф', 'д'), 2),
#  (('с', 'н'), 2),
#  (('э', 'х'), 2),
#  (('м', 'к'), 2),
#  (('л', 'ж'), 2),
#  (('й', 'ж'), 2),
#  (('я', 'к'), 2),
#  (('б', 'р'), 2),
#  (('т', 'э'), 2),
#  (('к', 'й'), 2),
#  (('ц', 'н'), 2),
#  (('ш', 'я'), 2),
#  (('н', 'э'), 2),
#  (('б', 'с'), 2),
#  (('а', 'ш'), 2),
#  (('ш', 'л'), 2),
#  (('ъ', 'е'), 2),
#  (('п', 'я'), 2),
#  (('б', 'й'), 2),
#  (('х', 'о'), 2),
#  (('я', 'х'), 2),
#  (('й', 'п'), 2),
#  (('а', 'ц'), 2),
#  (('о', 'ф'), 2),
#  (('у', 'п'), 2),
#  (('д', 'ш'), 2),
#  (('ц', 'г'), 2),
#  (('т', 'ю'), 2),
#  (('ь', 'з'), 2),
#  (('т', 'ж'), 2),
#  (('а', 'б'), 2),
#  (('й', 'б'), 2),
#  (('б', 'н'), 2),
#  (('з', 'н'), 2),
#  (('ю', 'й'), 1),
#  (('ю', 'я'), 1),
#  (('п', 'н'), 1),
#  (('ч', 'й'), 1),
#  (('л', 'ш'), 1),
#  (('ъ', 'ю'), 1),
#  (('ч', 'ф'), 1),
#  (('а', 'щ'), 1),
#  (('ш', 'й'), 1),
#  (('ы', 'ц'), 1),
#  (('ж', 'г'), 1),
#  (('ф', 'н'), 1),
#  (('щ', 'ф'), 1),
#  (('в', 'ш'), 1),
#  (('ж', 'н'), 1),
#  (('п', 'л'), 1),
#  (('з', 'г'), 1),
#  (('у', 'ч'), 1),
#  (('ф', 'й'), 1),
#  (('щ', 'х'), 1),
#  (('х', 'я'), 1),
#  (('х', 'й'), 1),
#  (('ж', 'я'), 1),
#  (('ю', 'ц'), 1),
#  (('ъ', 'д'), 1),
#  (('ш', 'ц'), 1),
#  (('ц', 'к'), 1),
#  (('ъ', 'г'), 1),
#  (('ж', 'ы'), 1),
#  (('х', 'д'), 1),
#  (('ы', 'б'), 1),
#  (('х', 'ь'), 1),
#  (('а', 'ч'), 1),
#  (('щ', 'е'), 1),
#  (('я', 'в'), 1),
#  (('х', 'з'), 1),
#  (('ю', 'в'), 1),
#  (('ж', 'ю'), 1),
#  (('т', 'х'), 1),
#  (('х', 'н'), 1),
#  (('п', 'у'), 1),
#  (('ю', 'с'), 1),
#  (('ь', 'п'), 1),
#  (('я', 'з'), 1),
#  (('з', 'м'), 1),
#  (('ш', 'д'), 1),
#  (('ы', 'ж'), 1),
#  (('ч', 'г'), 1),
#  (('ш', 'р'), 1),
#  (('ъ', '-'), 1),
#  (('е', 'п'), 1),
#  (('н', 'ф'), 1),
#  (('щ', 'т'), 1),
#  (('и', 'ж'), 1),
#  (('з', 'э'), 1),
#  (('э', 'щ'), 1),
#  (('ф', 'я'), 1),
#  (('ь', '-'), 1),
#  (('ю', 'д'), 1),
#  (('з', 'к'), 1),
#  (('в', 'ц'), 1),
#  (('р', 'ч'), 1),
#  (('т', 'ъ'), 1),
#  (('г', 'э'), 1),
#  (('ъ', 'ш'), 1),
#  (('ъ', 'ы'), 1),
#  (('и', 'ш'), 1),
#  (('ю', 'к'), 1),
#  (('е', 'щ'), 1),
#  (('ц', 'э'), 1),
#  (('п', 'с'), 1),
#  (('ъ', 'ж'), 1),
#  (('я', 'ц'), 1),
#  (('а', 'ф'), 1),
#  (('ц', 'а'), 1),
#  (('я', 'ф'), 1),
#  (('ч', 'в'), 1),
#  (('г', 'с'), 1),
#  (('з', 'щ'), 1),
#  (('ы', 'д'), 1),
#  (('ы', 'р'), 1),
#  (('ш', 'ю'), 1),
#  (('п', 'м'), 1),
#  (('н', 'п'), 1),
#  (('м', 'ж'), 1),
#  (('у', 'ш'), 1),
#  (('м', 'г'), 1),
#  (('ы', 'к'), 1),
#  (('ж', 'к'), 1),
#  (('щ', 'з'), 1),
#  (('у', 'з'), 1),
#  (('к', 'ф'), 1),
#  (('с', 'ж'), 1),
#  (('б', 'ц'), 1),
#  (('я', 'б'), 1),
#  (('в', 'ч'), 1),
#  (('б', 'э'), 1),
#  (('ф', 'г'), 1),
#  (('ф', 'м'), 1),
#  (('я', 'д'), 1),
#  (('г', 'п'), 1),
#  (('б', 'щ'), 1),
#  (('я', 'ч'), 1),
#  (('к', 'ч'), 1),
#  (('к', 'ж'), 1),
#  (('у', '-'), 1),
#  ((' ', 'ъ'), 1),
#  (('у', 'э'), 1),
#  (('а', 'х'), 1),
#  (('т', 'щ'), 1),
#  (('х', 'л'), 1),
#  (('е', 'ф'), 1),
#  (('з', 'л'), 1),
#  (('м', 'р'), 1),
#  (('ю', 'б'), 1),
#  (('б', 'з'), 1),
#  (('з', 'п'), 1),
#  (('л', 'ф'), 1),
#  (('ж', 'м'), 1),
#  (('о', 'щ'), 1)]

# %%
all_errors_d = Counter([tup[1:] for _, row in train_df.iterrows() for tup in align(row[1], row[4]) if tup[0] == 'D'])
all_errors_d = sorted(all_errors_d.items(), key=lambda error: -error[1])
all_errors_d
# Out:
# [(('о', '#'), 2944),
#  ((' ', '#'), 2175),
#  (('й', '#'), 779),
#  (('ь', '#'), 773),
#  (('д', '#'), 739),
#  (('р', '#'), 687),
#  (('а', '#'), 642),
#  (('т', '#'), 632),
#  (('с', '#'), 610),
#  (('л', '#'), 609),
#  (('е', '#'), 514),
#  (('и', '#'), 509),
#  (('н', '#'), 361),
#  (('в', '#'), 289),
#  (('у', '#'), 280),
#  (('м', '#'), 258),
#  (('я', '#'), 218),
#  (('к', '#'), 216),
#  (('э', '#'), 166),
#  (('ы', '#'), 134),
#  (('г', '#'), 118),
#  (('ц', '#'), 107),
#  (('п', '#'), 100),
#  (('ф', '#'), 99),
#  (('з', '#'), 77),
#  (('б', '#'), 76),
#  (('ж', '#'), 68),
#  (('х', '#'), 60),
#  (('ч', '#'), 59),
#  (('ш', '#'), 47),
#  (('ъ', '#'), 42),
#  (('ю', '#'), 13)]

# %%
all_errors_i = Counter([tup[1:] for _, row in train_df.iterrows() for tup in align(row[1], row[4]) if tup[0] == 'I'])
all_errors_i = sorted(all_errors_i.items(), key=lambda error: -error[1])
all_errors_i
# Out:
# [(('%', ' '), 14030),
#  (('%', 'а'), 3192),
#  (('%', 'е'), 2480),
#  (('%', 'о'), 2148),
#  (('%', 'и'), 1781),
#  (('%', 'в'), 1115),
#  (('%', 'ы'), 1095),
#  (('%', 'т'), 1054),
#  (('%', 'ь'), 1053),
#  (('%', 'л'), 919),
#  (('%', 'й'), 858),
#  (('%', 'э'), 808),
#  (('%', 'у'), 760),
#  (('%', 'н'), 689),
#  (('%', 'к'), 576),
#  (('%', 'м'), 556),
#  (('%', 'я'), 503),
#  (('%', 'д'), 489),
#  (('%', 'с'), 470),
#  (('%', 'р'), 456),
#  (('%', 'п'), 320),
#  (('%', 'г'), 218),
#  (('%', 'з'), 152),
#  (('%', 'х'), 122),
#  (('%', 'ш'), 117),
#  (('%', 'ю'), 100),
#  (('%', 'ч'), 83),
#  (('%', 'б'), 83),
#  (('%', 'ц'), 66),
#  (('%', 'ж'), 49),
#  (('%', 'ф'), 48),
#  (('%', '-'), 14),
#  (('%', 'щ'), 13),
#  (('%', 'ъ'), 6)]

# %%
errors_s = [error[0] for error in all_errors_s[0:23]]
errors_d = [error[0][0]for error in all_errors_d[0:2]]
errors_i = [error[0][1] for error in all_errors_i[0:0]]

# %%
word_counts = Counter(
    [word for utterance in tokenized_texts for word in utterance]
)

# %%
def best_del(sentence: str) -> str:
    dels = del_smth(sentence)
    dels.extend([x2_edited for edited in dels for x2_edited in del_smth(edited)])
    return best_char(dels)[0]

def edit(sentence: str) -> Set[str]:
    sentence = best_del(sentence)
    splits = [(sentence[:i], sentence[i:]) for i in range(len(sentence) + 1)]
    subs = [left + right[1:] for left, right in splits for tup in ]
    dels = [s.replace('  ', ' ').strip() for s in dels]

def my_edit(sentence: str) -> Iterable[str]:
    splits = [(sentence[:i], sentence[i:]) for i in range(len(sentence) + 1)]
    dels = [left + right[1:] for left, right in splits if right[:1] in errors_d]
    dels = [s.replace('  ', ' ').strip() for s in dels]
    return set(dels)

# def concat_smth(sentence: str) -> Iterable[str]:
#     words = sentence.split()
#     options = []
#     for i in range(1, len(words)):
#         if words[i - 1] in word_counts and len(words[i - 1]) > 2:
#             if words[i] in word_counts and len(words[i]) > 2:
#                 continue
#         options.append(' '.join(words[:i - 1]  + [words[i - 1] + words[i]] + words[i + 1:]))
#     return options

def del_smth(sentence: str) -> Set[str]:
    splits = [(sentence[:i], sentence[i:]) for i in range(len(sentence) + 1)]
    dels = [left + right[1:] for left, right in splits if right[:1] in errors_d]
    dels = [s.replace('  ', ' ').strip() for s in dels]
    return dels    


def two_my_edits(sentence: str) -> Set[str]:
    x1_edited = my_edit(sentence)
    return {x2_edited for edited in x1_edited for x2_edited in my_edit(edited)}

def two_edits(sentence: str) -> Set[str]:
    return {te for oe in best_char(one_edit(sentence), n=100) for te in one_edit(oe)}

def three_edits(sentence: str) -> Set[str]:
    return {te for oe in best_char(two_edits(sentence), n=3) for te in one_edit(oe)}

def correct(sentence: str) -> str:

    candidates = one_edit(sentence) | {sentence}
    return best(candidates)

# %%
'дай' in word_counts
# Out:
# True

# %%
one_edit('дать ксен и и')
# Out:
# ['датьксен и и',
#  'дать ксени и',
#  'дать ксен ии',
#  'датьксени и',
#  'датьксен ии',
#  'датьксени и',
#  'дать ксении',
#  'датьксен ии',
#  'дать ксении']

# %%
def correct_w2v(row):
    return correct(row['w2v'])

def correct_w2v_tts(row):
    return correct(row['w2v_tts'])

def correct_qnet(row):
    return correct(row['qnet'])

def correct_agg_text(row):
    return correct(row['agg_text'])

# %%
# %%time

val_df['w2v_corrected'] = val_df.apply(correct_w2v, axis=1)
val_df['w2v_tts_corrected'] = val_df.apply(correct_w2v_tts, axis=1)
val_df['qnet_corrected'] = val_df.apply(correct_qnet, axis=1)
# Out:
# CPU times: total: 1min 24s
# Wall time: 1min 26s

# %%
val_df[0:1000].apply(correct_w2v, axis=1)
# Out:
# 1             антонине татаринвый
# 6                    илюши власов
# 7                        терехину
# 19                      аидарчике
# 21      ксении валеревны волковой
#                   ...
# 4798                       а напи
# 4801                      мы купм
# 4818                      боготол
# 4819                 блун фонтейн
# 4821                  нижней туре
# Length: 1000, dtype: object

# %%
MODEL_LIST = ['qnet', 'w2v', 'w2v_tts', 'qnet_corrected', 'w2v_corrected', 'w2v_tts_corrected']
# MODEL_LIST = ['w2v_corrected']
MODEL_LIST
# Out:
# ['qnet',
#  'w2v',
#  'w2v_tts',
#  'qnet_corrected',
#  'w2v_corrected',
#  'w2v_tts_corrected']

# %%
max_likelihood_utterances = val_df.apply(
    lambda row: best_char(row[model] for model in MODEL_LIST)[0],
    axis=1,
)
method2wer = get_wer()
# method2wer["w2v_corrected"] = wer(hyps=val_df["text"], refs=val_df["w2v_corrected"])
method2wer["rescoring"] = wer(hyps=val_df["text"], refs=max_likelihood_utterances)
method2wer
# Out:
#   0%|          | 0/12354 [00:00<?, ?it/s]
#   0%|          | 0/12354 [00:00<?, ?it/s]
#   0%|          | 0/12354 [00:00<?, ?it/s]
#   0%|          | 0/12354 [00:00<?, ?it/s]
#   0%|          | 0/12354 [00:00<?, ?it/s]
#   0%|          | 0/12354 [00:00<?, ?it/s]
#   0%|          | 0/12354 [00:00<?, ?it/s]
# | method            |   WER, % |
# |-------------------+----------|
# | qnet              |    94.87 |
# | qnet_corrected    |    91.97 |
# | w2v_tts_corrected |    74.76 |
# | w2v_tts           |    71.06 |
# | w2v_corrected     |    69.53 |
# | w2v               |    65.46 |
# | rescoring         |    48.66 |

# %% [markdown]
# ## Сгенерируем новый вариант с помощью ROVER

# %%
def get_rover_df(
    df: pd.DataFrame, model_cols: List[str], tmp_col: str = "__tmp"
) -> pd.DataFrame:
    rover_df = df.copy()

    if "text" in rover_df.columns:
        rover_df.drop("text", axis=1, inplace=True)

    rover_df[tmp_col] = rover_df.apply(
        lambda row: [(model, row[model]) for model in model_cols], axis=1
    )

    rover_df = rover_df.drop(model_cols, axis=1).explode(tmp_col)

    return pd.DataFrame(
        {
            "task": rover_df["task"],
            "performer": rover_df[tmp_col].apply(lambda x: x[0]),
            "text": rover_df[tmp_col].apply(lambda x: x[1]),
        }
    )

# %%
MODEL_LIST = [
 'qnet_corrected',
 'w2v_corrected',
 'w2v_tts_corrected',
]

# %%
val_rover_df = get_rover_df(val_df, model_cols=MODEL_LIST)
val_rover_df
# Out:
#                                    task          performer  \
# 1      3c2875271fb918da312865549d444653     qnet_corrected
# 1      3c2875271fb918da312865549d444653      w2v_corrected
# 1      3c2875271fb918da312865549d444653  w2v_tts_corrected
# 6      1254c97d2434297a886e4dc4b2a16863     qnet_corrected
# 6      1254c97d2434297a886e4dc4b2a16863      w2v_corrected
# ...                                 ...                ...
# 60911  f8df9effaf84f5aaa1f33c3e2cf4ad5a      w2v_corrected
# 60911  f8df9effaf84f5aaa1f33c3e2cf4ad5a  w2v_tts_corrected
# 60917  19fb11ac46e700873f80a0f615dad84c     qnet_corrected
# 60917  19fb11ac46e700873f80a0f615dad84c      w2v_corrected
# 60917  19fb11ac46e700873f80a0f615dad84c  w2v_tts_corrected
#
#                                                   text
# 1                                 онпанинето тариновый
# 1                                  антонине татаринвый
# 1                                  антонини татаринвый
# 6                                        илюши влассво
# 6                                         илюши власов
# ...                                                ...
# 60911  седьмой кассационныйсудобщей юрисдикции телефон
# 60911   седьмой касационный судобщейюрисдикции телефон
# 60917                                      вилка лошка
# 60917                                      вилка ложка
# 60917                                      вилка ложка
#
# [37062 rows x 3 columns]

# %%
rover_result = ROVER(tokenizer=list, detokenizer="".join, silent=False).fit_predict(
    val_rover_df
)
# Out:
#   0%|          | 0/12354 [00:00<?, ?it/s]

# %%
rover_result = pd.merge(val_df, rover_result.reset_index(), on="task")

# %%
rover_result
# Out:
#                                    task  \
# 0      3c2875271fb918da312865549d444653
# 1      1254c97d2434297a886e4dc4b2a16863
# 2      867e45b9a914fffff0c8ef976ee0a275
# 3      32d052f80c431869e7c13914b88f958e
# 4      719cbc316c0f3caa6324c110ad899b81
# ...                                 ...
# 12349  b2c4360bffc98f20b59fc6e6c3f1a606
# 12350  de0fd646bdd3b37697580c2cc2d7d624
# 12351  97d2af838eb539e5a7151b099e13498d
# 12352  f8df9effaf84f5aaa1f33c3e2cf4ad5a
# 12353  19fb11ac46e700873f80a0f615dad84c
#
#                                                     text  \
# 0                                   антонине татариновой
# 1                                          илюши власова
# 2                                               терехину
# 3                                              айдарчике
# 4                             ксении валерьевны волковой
# ...                                                  ...
# 12349                                         фармэконом
# 12350                                         ссср бронь
# 12351                                      фото салончик
# 12352  седьмой кассационный суд общей юрисдикции телефон
# 12353                                        вилка ложка
#
#                                                    qnet  \
# 0                                 онпанине то тариновый
# 1                                         илюши влассво
# 2                                             тере гину
# 3                                           а и дарчики
# 4                            сени и воверивны в волколы
# ...                                                 ...
# 12349                                      фар мы коном
# 12350                                    этозысер бронь
# 12351                                 хот то солоничиак
# 12352  седьмой катоционный суд общей юрисдикции телефон
# 12353                                       вилка лошка
#
#                                                      w2v  \
# 0                                   антонине татариновый
# 1                                         и люши власово
# 2                                               терехину
# 3                                              аидарчике
# 4                            к сени и валеревны волковой
# ...                                                  ...
# 12349                                         фар мконом
# 12350                                     эсососэр бронь
# 12351                                   фот -то солончик
# 12352  седьмой кассационный суд общей юрисдикции  тел...
# 12353                                        вилка ложка
#
#                                                 w2v_tts  \
# 0                                  антонини татариновый
# 1                                        и люше власова
# 2                                             терьехину
# 3                                           а и дарчике
# 4                           ксение ивалиревной волковой
# ...                                                 ...
# 12349                                       фар мыконон
# 12350                                    эсисыцар бронь
# 12351                                  фото солоничек а
# 12352  седьмой касационный суд общей юрисдикции телефон
# 12353                                       вилка ложка
#
#                                          w2v_corrected  \
# 0                                  антонине татаринвый
# 1                                         илюши власов
# 2                                             терехину
# 3                                            аидарчике
# 4                            ксении валеревны волковой
# ...                                                ...
# 12349                                        фар мконм
# 12350                                   эсососэр бронь
# 12351                                  фт -то солончик
# 12352  седьмой кассационныйсудобщей юрисдикции телефон
# 12353                                      вилка ложка
#
#                                     w2v_tts_corrected  \
# 0                                 антонини татаринвый
# 1                                       илюше власова
# 2                                           терьехину
# 3                                         а и дарчике
# 4                          ксениеивалиревной волковой
# ...                                               ...
# 12349                                       фар мыкнн
# 12350                                  эсисыцар бронь
# 12351                                 фото слоничек а
# 12352  седьмой касационный судобщейюрисдикции телефон
# 12353                                     вилка ложка
#
#                                        qnet_corrected  \
# 0                                онпанинето тариновый
# 1                                       илюши влассво
# 2                                           тере гину
# 3                                         а и дарчики
# 4                            сении воверивныв волколы
# ...                                               ...
# 12349                                      фар мыконм
# 12350                                  этозысер бронь
# 12351                                 хот тослоничиак
# 12352  седьмой катоционныйсудобщей юрисдикции телефон
# 12353                                     вилка лошка
#
#                                              agg_text
# 0                                 антонине татаринвый
# 1                                       илюши власово
# 2                                            терехину
# 3                                         а и дарчике
# 4                          ксении валеревный волковой
# ...                                               ...
# 12349                                      фар мыконм
# 12350                                  эсосысэр бронь
# 12351                                  фт то слоничик
# 12352  седьмой касационныйсудобщей юрисдикции телефон
# 12353                                     вилка ложка
#
# [12354 rows x 9 columns]

# %%
val_df = rover_result

# %%
val_df['agg_text_corrected'] = val_df.apply(correct_agg_text, axis=1)

# %%
MODEL_LIST = ['qnet', 'qnet_corrected', 'w2v', 'w2v_tts', 'w2v_corrected', 'w2v_tts_corrected', 'agg_text']

# %%
MODEL_LIST
# Out:
# ['qnet',
#  'qnet_corrected',
#  'w2v',
#  'w2v_tts',
#  'w2v_corrected',
#  'w2v_tts_corrected',
#  'agg_text']

# %%
best_char(['привет мир', 'првет мир'])[0]
# Out:
# 'привет мир'

# %%
MODEL_LIST = ['qnet', 'w2v', 'w2v_tts', 'qnet_corrected', 'w2v_corrected', 'w2v_tts_corrected', 'agg_text']

# %%
max_likelihood_utterances = val_df.apply(
    lambda row: best_char(row[model] for model in MODEL_LIST)[0],
    axis=1,
)
method2wer = get_wer()
# method2wer["agg_text"] = wer(hyps=val_df["text"], refs=val_df["agg_text"])
# method2wer["agg_text_corrected"] = wer(hyps=val_df["text"], refs=val_df["agg_text_corrected"])
method2wer["rescoring"] = wer(hyps=val_df["text"], refs=max_likelihood_utterances)
method2wer
# Out:
#   0%|          | 0/12354 [00:00<?, ?it/s]
#   0%|          | 0/12354 [00:00<?, ?it/s]
#   0%|          | 0/12354 [00:00<?, ?it/s]
#   0%|          | 0/12354 [00:00<?, ?it/s]
#   0%|          | 0/12354 [00:00<?, ?it/s]
#   0%|          | 0/12354 [00:00<?, ?it/s]
#   0%|          | 0/12354 [00:00<?, ?it/s]
#   0%|          | 0/12354 [00:00<?, ?it/s]
# | method            |   WER, % |
# |-------------------+----------|
# | qnet              |    94.87 |
# | qnet_corrected    |    91.97 |
# | w2v_tts_corrected |    74.76 |
# | w2v_tts           |    71.06 |
# | w2v_corrected     |    69.53 |
# | agg_text          |    68.85 |
# | w2v               |    65.46 |
# | rescoring         |    48.09 |
